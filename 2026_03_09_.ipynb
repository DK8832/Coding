# %% [markdown]
# <a href="https://colab.research.google.com/github/DK8832/Coding/blob/main/2026_03_09_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ㄱㄱㄱ
# ## ㄱㄱㄱ
# ### ㄱㄱㄱ
# #### ㄱㄱㄱ
# ##### ㄱㄱㄱ
# **ㄱㄱㄱ**
# *ㄱㄱㄱ*
# _ㄱㄱㄱ_
# ~~ㄱㄱㄱ~~
# `print("ㄱㄱㄱ")`
# * ㄱㄱㄱ
# - ㄱㄱㄱ
# [ㄱㄱㄱ](https://www.google.com/search?q=%E3%84%B1%E3%84%B1%E3%84%B1&sca_esv=3b36d53a0ad7b307&hl=ko&sxsrf=ANbL-n4oXhU-YpEdQF1YBpmwlxeVw0byDQ%3A1773039698527&source=hp&ei=UnCuadmeHvPQ2roP1LbqiAc&iflsig=AFdpzrgAAAAAaa5-YoZr6XI8wVNgrXIjr2w8DAbUBoc7&ved=0ahUKEwjZj5vLn5KTAxVzqFYBHVSbGnEQ4dUDCBo&uact=5&oq=%E3%84%B1%E3%84%B1%E3%84%B1&gs_lp=&sclient=gws-wiz)
# ![ㄱㄱㄱ](https://the.sfo2.cdn.digitaloceanspaces.com/dict/jaum/img/%E3%84%B1%E3%84%B1%E3%84%B1.png)
# $ ㄱㄱㄱ = ㄱㄱㄱ × ㄱㄱㄱ$

# %%
print('hello world!')
# Out:
# hello world!

# %%
#파이썬
def sum_num(a, b):
  return a+b

# %%
sum_num(919, 9239)
# Out:
# 10158

# %%
import random
print(random.randint(1, 10))
print(random.randbytes(10))
# Out:
# 8
# b'\xae\x06\x17^\xdb\xc7f\x80\xc3\xfa'

# %%
from random import*
print(randint(1, 10000))
# Out:
# 9962

# %%
random()
# Out:
# 0.009472572282908875

# %%
uniform(10, 20)
# Out:
# 16.468578864154285
